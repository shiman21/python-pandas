# %% [markdown]
# CSV-COMMA SEPERATED VALUES

# %% [markdown]
# ADVANTAGES OF CSV:

# %% [markdown]
# UNIVERSAL '\n'
# EASY TO UNDERSTAND'\n'
# QUICK TO CREATE'\n'

# %%
import pandas as pd
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
pd.read_csv('C:\\Users\\User\\Downloads\\Book1.csv')
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006          JAYESH JAYANANDAN    CSE      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    CSE      A1
# 6      ra1911003010014                 ALI ARAFAT    CSE      A1
# 7      ra1911003010015              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019            DEBORSHI LAHIRI    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE      A1
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12     ra1911003010024                ARYAN SINGH    CSE      A1
# ...

# %%
pd.read_csv('C:\\Users\\User\\Downloads\\book.csv')
# Out:
#    top MNC's in world
# 0              Amazon
# 1           Microsoft
# 2              Google
# 3                 TCS
# 4             Infosys
# 5               Wipro
# 6            Infotech
# 7          MasterCard
# 8          McDonald's
# 9             Alibaba
# 10                MSN
# 11           Facebook
# 12          Whirlpool
# 13                 LG

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\User\python tutorials\pandas
