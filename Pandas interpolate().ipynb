# %% [markdown]
# # PANDAS INTERPOLATE

# %% [markdown]
# Pandas interpolate() function is basically used to fill NaN values in dataframe or series

# %% [markdown]
# -Very powerful function

# %% [markdown]
# -Uses various interpolation techniques

# %% [markdown]
# syntax:

# %% [markdown]
# -DataFrame.interpolate()

# %% [markdown]
# -Series.interpolate()

# %%
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\User\Downloads\book1.csv')
df
# Out:
#       ID Registration Number                Name Branch Section  \
# 0    1.0     ra1911003010001      ABHINAV RANJAN    CSE      A1
# 1    2.0     ra1911003010003                 NaN    CSE      A1
# 2    3.0     ra1911003010006                 NaN    CSE      A1
# 3    NaN     ra1911003010007  AJAY SAMUEL VICTOR    CSE      A2
# 4    NaN     ra1911003010008           NANDA M P    CSE      A1
# 5    NaN     ra1911003010013          JOSHIKHA M    CSE      A1
# 6    7.0                 NaN          JOSHIKHA M    CSE      A2
# 7    8.0                 NaN       RASHI AGARWAL    CSE     NaN
# 8    9.0     ra1911003010016                 NaN    CSE     NaN
# 9    NaN     ra1911003010019                 NaN    CSE      A2
# 10  11.0     ra1911003010020         AISHWARYA B    CSE      A1
# 11   NaN     ra1911003010022      NISHANT MITTAL    CSE     NaN
# 12  13.0     ra1911003010022                 NaN    CSE     NaN
# 13  14.0                 NaN         ARYAN SINGH    CSE     NaN
# ...

# %%
df.interpolate()
# Out:
#       ID Registration Number                Name Branch Section  \
# 0    1.0     ra1911003010001      ABHINAV RANJAN    CSE      A1
# 1    2.0     ra1911003010003                 NaN    CSE      A1
# 2    3.0     ra1911003010006                 NaN    CSE      A1
# 3    4.0     ra1911003010007  AJAY SAMUEL VICTOR    CSE      A2
# 4    5.0     ra1911003010008           NANDA M P    CSE      A1
# 5    6.0     ra1911003010013          JOSHIKHA M    CSE      A1
# 6    7.0                 NaN          JOSHIKHA M    CSE      A2
# 7    8.0                 NaN       RASHI AGARWAL    CSE     NaN
# 8    9.0     ra1911003010016                 NaN    CSE     NaN
# 9   10.0     ra1911003010019                 NaN    CSE      A2
# 10  11.0     ra1911003010020         AISHWARYA B    CSE      A1
# 11  12.0     ra1911003010022      NISHANT MITTAL    CSE     NaN
# 12  13.0     ra1911003010022                 NaN    CSE     NaN
# 13  14.0                 NaN         ARYAN SINGH    CSE     NaN
# ...

# %%
df.interpolate(method='linear')# same as deafult
# Out:
#       ID Registration Number                Name Branch Section  \
# 0    1.0     ra1911003010001      ABHINAV RANJAN    CSE      A1
# 1    2.0     ra1911003010003                 NaN    CSE      A1
# 2    3.0     ra1911003010006                 NaN    CSE      A1
# 3    4.0     ra1911003010007  AJAY SAMUEL VICTOR    CSE      A2
# 4    5.0     ra1911003010008           NANDA M P    CSE      A1
# 5    6.0     ra1911003010013          JOSHIKHA M    CSE      A1
# 6    7.0                 NaN          JOSHIKHA M    CSE      A2
# 7    8.0                 NaN       RASHI AGARWAL    CSE     NaN
# 8    9.0     ra1911003010016                 NaN    CSE     NaN
# 9   10.0     ra1911003010019                 NaN    CSE      A2
# 10  11.0     ra1911003010020         AISHWARYA B    CSE      A1
# 11  12.0     ra1911003010022      NISHANT MITTAL    CSE     NaN
# 12  13.0     ra1911003010022                 NaN    CSE     NaN
# 13  14.0                 NaN         ARYAN SINGH    CSE     NaN
# ...

# %%
df.interpolate(method='linear')#valid only when dataframe contains date and time
