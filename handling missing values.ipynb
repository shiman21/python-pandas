# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv')

df
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                        NaN    NaN      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    NaN      A1
# 6      ra1911003010014                  no values    CSE     NaN
# 7                  NaN              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019              not available    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE     NaN
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12                 NaN                ARYAN SINGH    CSE      A1
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',na_values='not available')#na_values will change the given string to NaN 
df
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                        NaN    NaN      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    NaN      A1
# 6      ra1911003010014                  no values    CSE     NaN
# 7                  NaN              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019                        NaN    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE     NaN
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12                 NaN                ARYAN SINGH    CSE      A1
# ...

# %% [markdown]
# #N/A will also print NaN

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',na_values=['not available','no values'])#na_values will change the given string to NaN 
df
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                        NaN    NaN      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    NaN      A1
# 6      ra1911003010014                        NaN    CSE     NaN
# 7                  NaN              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019                        NaN    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE     NaN
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12                 NaN                ARYAN SINGH    CSE      A1
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',na_values={'Name':'no values'})#to specify only some spaces as NaN we use dictionary
df
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                        NaN    NaN      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    NaN      A1
# 6      ra1911003010014                        NaN    CSE     NaN
# 7                  NaN              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019              not available    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE     NaN
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12                 NaN                ARYAN SINGH    CSE      A1
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',na_values={'Name':'no values','LoginId':'not available'})#to specify only some spaces as NaN we use dictionary
df
# Out:
#    Registration Number                       Name Branch Section  \
# 0      ra1911003010001  KODURU SIVA GOWTHAM REDDY    CSE      A1
# 1      ra1911003010003             ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                        NaN    NaN      A1
# 3      ra1911003010007         AJAY SAMUEL VICTOR    CSE      A1
# 4      ra1911003010008                  NANDA M P    CSE      A1
# 5      ra1911003010013                 JOSHIKHA M    NaN      A1
# 6      ra1911003010014                        NaN    CSE     NaN
# 7                  NaN              RASHI AGARWAL    CSE      A1
# 8      ra1911003010016      PURNA CHANDRA PAVAN K    CSE      A1
# 9      ra1911003010019              not available    CSE      A1
# 10     ra1911003010020                AISHWARYA B    CSE     NaN
# 11     ra1911003010022             NISHANT MITTAL    CSE      A1
# 12                 NaN                ARYAN SINGH    CSE      A1
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',keep_default_na=False)# keep _default_na is used to keep tha null values as they are
df
# Out:
#    Registration Number                Name Branch Section  \
# 0      ra1911003010001                NULL    CSE      A1
# 1      ra1911003010003      ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                #N/A             A1
# 3      ra1911003010007  AJAY SAMUEL VICTOR    CSE    NULL
# 4      ra1911003010008           NANDA M P    CSE      A1
# 5      ra1911003010013          JOSHIKHA M             A1
# 6      ra1911003010014           no values    CSE
# 7                            RASHI AGARWAL    CSE      A1
# 8      ra1911003010016                NULL    CSE      A1
# 9      ra1911003010019       not available    CSE      A1
# 10     ra1911003010020         AISHWARYA B    CSE
# 11     ra1911003010022      NISHANT MITTAL    CSE      A1
# 12                             ARYAN SINGH    CSE      A1
# 13     ra1911003010025                        CSE      A1
# 14     ra1911003010027         ANSH KAKKAR    CSE      A1
#
#                 LoginId  Password
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',keep_default_na=True)# keep _default_na is used to keep tha null values as they are
df
# Out:
#    Registration Number                Name Branch Section  \
# 0      ra1911003010001                 NaN    CSE      A1
# 1      ra1911003010003      ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006                 NaN    NaN      A1
# 3      ra1911003010007  AJAY SAMUEL VICTOR    CSE     NaN
# 4      ra1911003010008           NANDA M P    CSE      A1
# 5      ra1911003010013          JOSHIKHA M    NaN      A1
# 6      ra1911003010014           no values    CSE     NaN
# 7                  NaN       RASHI AGARWAL    CSE      A1
# 8      ra1911003010016                 NaN    CSE      A1
# 9      ra1911003010019       not available    CSE      A1
# 10     ra1911003010020         AISHWARYA B    CSE     NaN
# 11     ra1911003010022      NISHANT MITTAL    CSE      A1
# 12                 NaN         ARYAN SINGH    CSE      A1
# 13     ra1911003010025                 NaN    CSE      A1
# 14     ra1911003010027         ANSH KAKKAR    CSE      A1
#
# ...

# %%
df=pd.read_csv(r'C:\Users\User\Downloads\book1.csv',na_filter=False)
df
# Out:
#    Registration Number                Name Branch Section  \
# 0      ra1911003010001      ABHINAV RANJAN    CSE      A1
# 1      ra1911003010003      ABHINAV RANJAN    CSE      A1
# 2      ra1911003010006      ABHINAV RANJAN    CSE      A1
# 3      ra1911003010007  AJAY SAMUEL VICTOR    CSE      A2
# 4      ra1911003010008           NANDA M P    CSE      A1
# 5      ra1911003010013          JOSHIKHA M    CSE      A1
# 6      ra1911003010014          JOSHIKHA M    CSE      A2
# 7      ra1911003010014       RASHI AGARWAL    CSE      A1
# 8      ra1911003010016       RASHI AGARWAL    CSE      A1
# 9      ra1911003010019       RASHI AGARWAL    CSE      A2
# 10     ra1911003010020         AISHWARYA B    CSE      A1
# 11     ra1911003010022      NISHANT MITTAL    CSE      A1
# 12     ra1911003010022         ARYAN SINGH    CSE      A1
# 13     ra1911003010025         ARYAN SINGH    CSE      A1
# 14     ra1911003010027         ANSH KAKKAR    CSE      A1
#
# ...
